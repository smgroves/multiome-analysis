# %% [markdown]
# # Unsupervised and supervised archetype analysis on combined dataset (raw and scanorama)

# %%
# import mazebox as mb
import scvelo as scv
import scanpy as sc
import os.path as op
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sys
import dropkick as dk
import mazebox as mb
import cellrank as cr
import scanorama
from scipy.spatial.distance import squareform
from scipy.sparse import issparse, csr_matrix, find
from scipy.spatial.distance import pdist
from py_pcha import PCHA
from sklearn.utils import shuffle
from matplotlib.colors import CenteredNorm

# %%
adata = sc.read_h5ad('../../data/combined/adata_01_filtered.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8908 × 16719
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'sample_x', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase', 'brcd', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'barcode', 'sample_y', 'ATAC_snn_res.0.5', 'seurat_clusters', 'nCount_peaks', 'nFeature_peaks', 'peaks_snn_res.0.5', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'SCT.weight', 'peaks.weight', 'nCount_Imputed_counts', 'nFeature_Imputed_counts', 'nCount_gene_activity', 'nFeature_gene_activity', 'NE_score1', 'identity', 'non.NE_score1', 'comb.score', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'wsnn_res.0.5'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-M1', 'dropkick_coef-M2', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'identity_colors', 'neighbors', 'pca', 'sample_colors', 'sample_x_colors', 'scanorama_neighbors', 'umap'
#     obsm: 'X_pca', 'X_scanorama', 'X_scanorama_umap', 'X_umap', 'X_umap_wnn', 'corrected'
#     varm: 'PCs'
#     layers: 'ambiguous', 'arcsinh_norm', 'log1p_norm', 'matrix', 'raw_counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances', 'scanorama_neighbors_connectivities', 'scanorama_neighbors_distances'

# %% [markdown]
# ## MAGIC

# %% [markdown]
# For stronger PCHA, we'll run MAGIC.

# %%
import magic
# import pandas as pd
# import matplotlib.pyplot as plt
magic_operator = magic.MAGIC(solver='approximate')
X_magic = magic_operator.fit_transform(adata)
# Out:
# Calculating MAGIC...
#   Running MAGIC on 8908 cells and 16719 genes.
#   Calculating graph and diffusion operator...
#     Calculating PCA...
#     Calculated PCA in 6.44 seconds.
#     Calculating KNN search...
#     Calculated KNN search in 10.47 seconds.
#     Calculating affinities...
#     Calculated affinities in 12.51 seconds.
#   Calculated graph and diffusion operator in 29.47 seconds.
#   Calculating imputation...
#   Calculated imputation in 0.07 seconds.
# Calculated MAGIC in 33.55 seconds.

# %%
sc.pp.pca(X_magic)

# %%
sc.pl.pca(X_magic, color=['sample_x','identity'])

# %%
scv.pp.neighbors(X_magic, random_state=0)
scv.tl.umap(X_magic, random_state=0)
# Out:
# computing neighbors
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
#     finished (0:00:13) --> added
#     'distances' and 'connectivities', weighted adjacency matrices (adata.obsp)

# %%
scv.pl.umap(X_magic,color=['sample_x','identity'])

# %%
X_magic
# Out:
# AnnData object with n_obs × n_vars = 8908 × 16719
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'sample_x', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase', 'brcd', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'barcode', 'sample_y', 'ATAC_snn_res.0.5', 'seurat_clusters', 'nCount_peaks', 'nFeature_peaks', 'peaks_snn_res.0.5', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'SCT.weight', 'peaks.weight', 'nCount_Imputed_counts', 'nFeature_Imputed_counts', 'nCount_gene_activity', 'nFeature_gene_activity', 'NE_score1', 'identity', 'non.NE_score1', 'comb.score', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'wsnn_res.0.5'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-M1', 'dropkick_coef-M2', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'pca', 'sample_x_colors', 'identity_colors', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
sc.pl.pca_variance_ratio(X_magic)

# %%
pca_var = X_magic.uns['pca']['variance_ratio']
var_explained = .90
tot_exp_var = 0
n = 0
for i in pca_var:
    n +=1
    tot_exp_var += i
    if tot_exp_var > var_explained: 
        print(n+1, "PCs explain at least", var_explained*100, "percent of the variance")
        break
# Out:
# 6 PCs explain at least 90.0 percent of the variance

# %%
def cumulative(var):
    cum_var = []
    tot_sum = 0
    for i in var:
        tot_sum += i
        cum_var.append(tot_sum)
    return cum_var

# %%
cum_var = cumulative(pca_var)
cum_var[7]
# Out:
# 0.9545548167079687

# %%
def find_knee_varexpl(cum_var):
    farthestk = 0
    for i in range(50):
        #find distance of point p3 from line between p1 and p2
        p1=np.array([0,cum_var[0]])
        p2=np.array([49,cum_var[49]])
        p3=np.array([i,cum_var[i]])
        k = (np.cross(p2-p1,p3-p1)/np.linalg.norm(p2-p1))

        #knee is farthest away from line between p1 and p2
        if k > farthestk: 
            farthestk = k
            knee = i
    return knee +1 # number of components is 1 more than index
print("Knee of EV vs PC plot: ",find_knee_varexpl(cum_var))
# Out:
# Knee of EV vs PC plot:  7

# %%
X_magic.write_h5ad('../../data/combined/X_magic.h5ad')

# %% [markdown]
# ## PCHA prep

# %%
# !pip install py_pcha

# %%
def find_knee(ev_per_arc, kmax):
    farthestk = 0
    for i in range(3,kmax):
        #find distance of point p3 from line between p1 and p2
        p1=np.array([3,ev_per_arc[0]])
        p2=np.array([kmax,ev_per_arc[kmax-3]])
        p3=np.array([i,ev_per_arc[i-3]])
        k = (np.cross(p2-p1,p3-p1)/np.linalg.norm(p2-p1))

        #knee is farthest away from line between p1 and p2
        if k > farthestk: 
            farthestk = k
            knee = i
    print("K* =",knee, "archetypes, distance between k* and line: ",np.round(farthestk,2))
    return knee, farthestk

# %% [markdown]
# # PCHA

# %%
# pca_var = X_magic_no_doublets.uns['pca']['variance_ratio']
# cum_var = cumulative(pca_var)

# print("Knee of EV vs PC plot: ",find_knee_varexpl(cum_var))

# %%
ev_per_arc = []
for i in range(3,11):
    XC, S, C, SSE, varexpl = PCHA(X_magic.obsm['X_pca'][:,0:7].T, noc=i, delta=0.1)
    ev_per_arc.append(varexpl)
    print(varexpl)
plt.scatter(x = [3,4,5,6,7,8,9,10], y = ev_per_arc)
plt.title(f"EV per $k^*$ archetypes on 10 component PCA projection, delta = 0.1")
plt.xlabel("Number of archetypes")
plt.ylabel("EV fraction")
print("Knee in EV vs k plot for different k_max:")
for kmax in range(8,11):
    print('k_max =', kmax)
    knee, farthestk = find_knee(ev_per_arc, kmax=kmax)
plt.axvline(x=knee, linestyle = "--")
plt.show()
# Out:
# 0.8486202167849811
# 0.8789227178723875
# 0.9306314674871284
# 0.9551748819135182
# 0.9688348473615126
# 0.9899891508658599
# 0.9919412802435581
# 0.9920576390893071
# Knee in EV vs k plot for different k_max:
# k_max = 8
# K* = 5 archetypes, distance between k* and line:  0.03
# k_max = 9
# K* = 6 archetypes, distance between k* and line:  0.03
# k_max = 10
# K* = 6 archetypes, distance between k* and line:  0.05

# %%
XC, S, C, SSE, varexpl = PCHA(X_magic.obsm['X_pca'][:,0:7].T, noc=6, delta=0)
XC = np.array(XC)
for components in ['1,2','1,3','2,3']:
    scv.pl.pca(X_magic, color = 'identity', components=components, show=False, figsize= (6,6), frameon=True)
    comp = components.split(',')
    plt.scatter(XC[int(comp[0])-1], XC[int(comp[1])-1], color = 'green', s = 200)
    plt.xlabel("PC"+comp[0])
    plt.ylabel("PC"+comp[1])

    plt.show()

# %%
# adata_U, umap = mb.pl.umap_update(adata, copy=True, method = "umap_original")

# %%
# XC_umap = umap.transform(XC.T).T

# %%
# sc.pl.scatter(adata_U, basis = 'umap_orig', color = "identity",show=False, frameon=True)
# plt.scatter(XC_umap[0], XC_umap[1], color = 'green', s = 200)
# plt.show()

# %% [markdown]
# ## Labeling cells based on diffusion distance to archetypes
# From Van Dijk et al:
# An archetype is a weighted sum of cells, which allows us to construct archetypal-neighborhoods, consisting of cells most similar to the archetype. The neighborhoods are constructed by assigning cells to their nearest archetype based on the diffusion distance, as long as this distance is within a bounded proximity from the archetype. Diffusion distance is defined as the Euclidean distance on the diffusion map representation of the data, i.e., using diffusion components as a coordinate system (Nadler et al., 2006), denoted by DM(t).

# %%
XC_df = pd.DataFrame(XC)
XC_df.columns = ['Arc_1','Arc_2','Arc_3','Arc_4','Arc_5', "Arc_6"]

# %%
X_magic_pca_df = pd.DataFrame(X_magic.obsm['X_pca'][:,0:7], index = X_magic.obs_names)
X_magic_full_df = X_magic_pca_df.append(XC_df.T)
X_magic_full_df.head()
# Out:
#                                                       0         1         2  \
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1  -5.487069 -4.728208 -0.274789
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1  -8.391650 -4.576259 -0.126386
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1 -10.669321  4.233021 -0.441058
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1  -9.421063 -4.166827 -0.503608
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1  -8.642355 -4.448038 -0.539649
#
#                                                      3         4         5  \
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1 -1.216845  0.464416 -1.073429
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1 -1.439424  1.067810 -0.600305
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1  1.847779 -0.085097  0.160481
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1 -1.019718  0.982071 -0.626454
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1 -1.668627  0.520869 -0.282774
#
#                                                      6
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1  0.771162
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1  1.119351
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1 -2.313472
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1  0.927567
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1  1.005649

# %%
pdx = squareform(pdist(X_magic_full_df, metric='euclidean')) # compute distances on pca
pdx_df = pd.DataFrame(pdx, index=X_magic_full_df.index, columns=X_magic_full_df.index)
pdx_df = pdx_df.loc[XC_df.columns].drop(XC_df.columns, axis = 1)
X_magic.obsm['arc_distance'] = pdx_df.T

# %% [markdown]
# Now that we have a euclidean distance to each archetype on the MAGIC imputed data, we can find a neighborhood with arbritrary radius to classify cells closest to each archetype as specialists. In Van Dijk et al., they choose a radius (distance on diffusion map) that is 1/2 the minimum of the distance between archetypes.

# %%
pdx_archetypes = squareform(pdist(XC_df.T, metric='euclidean')) # compute distances on pca

radius = .5*pdx_archetypes[pdx_archetypes > 0].min()

# %%
tmp = X_magic.obsm['arc_distance'].copy()

# %%
# percent_radius = .1 # in percentage of datapoints; radius = .1 means 10% closest cells to each archetype

for arc in  X_magic.obsm['arc_distance'].columns:
    closest = X_magic.obsm['arc_distance'].loc[X_magic.obsm['arc_distance'][arc].sort_values() < radius]
    tmp.loc[closest.index,'specialist'] = arc

# %%
tmp.specialist
# Out:
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1      NaN
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1    Arc_5
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1    Arc_6
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1    Arc_5
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1    Arc_5
#                                                 ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2      NaN
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2    Arc_1
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2    Arc_1
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2    Arc_1
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2    Arc_1
# Name: specialist, Length: 8908, dtype: object

# %%
X_magic.obs['specialists_pca_diffdist'] = tmp.specialist

# %% [markdown]
# ## Labeling by PCHA

# %%
for i in range(6):
    scv.pl.umap(X_magic, c = [S[i,:].T, 'identity'], components='1,2', show=False, figsize= (5,5), frameon=True, cmap = 'RdBu')
    plt.title(f"Archetype {i}")
    # plt.savefig(f'./figures/unsupervised_AA_magic/{i}_scPCHA_pca.pdf')

# %%
S_df = pd.DataFrame(S.T)

# %%
S_df.index = X_magic.obs_names

# %%
X_magic.obsm['py_pcha_S'] = S.T

# %%
X_magic
# Out:
# AnnData object with n_obs × n_vars = 8908 × 16719
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'sample_x', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase', 'brcd', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'barcode', 'sample_y', 'ATAC_snn_res.0.5', 'seurat_clusters', 'nCount_peaks', 'nFeature_peaks', 'peaks_snn_res.0.5', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'SCT.weight', 'peaks.weight', 'nCount_Imputed_counts', 'nFeature_Imputed_counts', 'nCount_gene_activity', 'nFeature_gene_activity', 'NE_score1', 'identity', 'non.NE_score1', 'comb.score', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'wsnn_res.0.5', 'specialists_pca_diffdist'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-M1', 'dropkick_coef-M2', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'pca', 'sample_x_colors', 'identity_colors', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap', 'arc_distance', 'py_pcha_S'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 8908 × 16719
#     obs: 'dropkick_score', 'dropkick_label', 'arcsinh_n_genes_by_counts', 'sample_x', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts', 'log1p_total_counts', 'total_counts_mito', 'log1p_total_counts_mito', 'pct_counts_mito', 'total_counts_ambient', 'log1p_total_counts_ambient', 'pct_counts_ambient', 'arcsinh_total_counts', 'S_score', 'G2M_score', 'phase', 'brcd', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'barcode', 'sample_y', 'ATAC_snn_res.0.5', 'seurat_clusters', 'nCount_peaks', 'nFeature_peaks', 'peaks_snn_res.0.5', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'SCT.weight', 'peaks.weight', 'nCount_Imputed_counts', 'nFeature_Imputed_counts', 'nCount_gene_activity', 'nFeature_gene_activity', 'NE_score1', 'identity', 'non.NE_score1', 'comb.score', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'wsnn_res.0.5', 'specialists_pca_diffdist'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'dropkick_coef-M1', 'dropkick_coef-M2', 'mito', 'pct_dropout_by_counts', 'ambient', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'total_counts', 'log1p_total_counts', 'mean', 'std'
#     uns: 'identity_colors', 'neighbors', 'pca', 'sample_colors', 'sample_x_colors', 'scanorama_neighbors', 'umap'
#     obsm: 'X_pca', 'X_scanorama', 'X_scanorama_umap', 'X_umap', 'X_umap_wnn', 'corrected'
#     varm: 'PCs'
#     layers: 'ambiguous', 'arcsinh_norm', 'log1p_norm', 'matrix', 'raw_counts', 'spliced', 'unspliced'
#     obsp: 'connectivities', 'distances', 'scanorama_neighbors_connectivities', 'scanorama_neighbors_distances'

# %%
adata.obsm['arc_distance'] = pdx_df.T

# %%
S_df.columns = ['Arc_1','Arc_2','Arc_3','Arc_4','Arc_5', 'Arc_6']

# %%
adata.obsm['py_pcha_S'] = S_df

# %%
for c in adata.obsm['py_pcha_S']:
    adata.obs[f"{c}_PCHA_Score"] = adata.obsm['py_pcha_S'][c]

# %%
for i in range(6):
    scv.pl.scatter(adata, c = S[i,:].T, basis = "umap_wnn",components='1,2', show=False, figsize= (5,5), frameon=True, cmap = 'RdBu_r', smooth = True)
    plt.title(f"Archetype {i}")
    plt.show()

# %%
sc.pl.scatter(adata, basis = 'umap_wnn', color = ['specialists_pca_diffdist','identity'])

# %%
adata.obs
# Out:
#                                               dropkick_score dropkick_label  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1        0.190799          False
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1        0.270716          False
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1        0.323707          False
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1        0.193199          False
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1        0.268449          False
# ...                                                      ...            ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2        0.000000          False
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2        0.377218          False
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2        0.336164          False
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2        0.562490           True
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2        0.440802          False
#
#                                               arcsinh_n_genes_by_counts  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1                   6.419998
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1                   6.458341
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1                   6.100324
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1                   5.521477
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1                   6.342125
# ...                                                                 ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2                   6.396932
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2                   7.213769
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2                   7.054450
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2                   7.245656
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2                   7.340836
#
#                                              sample_x  initial_size_spliced  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1       M1                   603
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1       M1                   693
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1       M1                   487
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1       M1                   216
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1       M1                   608
# ...                                               ...                   ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2       M2                   435
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2       M2                   957
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2       M2                   785
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2       M2                   955
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2       M2                  1123
#
#                                               initial_size_unspliced  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1                     815
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1                    1079
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1                     551
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1                     400
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1                    1009
# ...                                                              ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2                     404
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2                    1898
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2                    4144
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2                    4207
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2                    4640
#
#                                               initial_size  n_genes_by_counts  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1         603.0                307
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1         693.0                319
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1         487.0                223
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1         216.0                125
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1         608.0                284
# ...                                                    ...                ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2         435.0                300
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2         957.0                679
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2         785.0                579
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2         955.0                701
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2        1123.0                771
#
#                                               log1p_n_genes_by_counts  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1                 5.730100
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1                 5.768321
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1                 5.411646
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1                 4.836282
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1                 5.652489
# ...                                                               ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2                 5.707110
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2                 6.522093
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2                 6.363028
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2                 6.553933
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2                 6.648985
#
#                                               total_counts  ...  Phase  \
# CellID                                                      ...
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1         603.0  ...     G1
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1         693.0  ...     G1
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1         487.0  ...      S
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1         216.0  ...      S
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1         608.0  ...     G1
# ...                                                    ...  ...    ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2         435.0  ...    G2M
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2         957.0  ...     G1
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2         785.0  ...      S
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2         954.0  ...     G1
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2        1123.0  ...     G1
#
#                                                  old.ident  wsnn_res.0.5  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1          NE_5           1.0
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1          NE_5           4.0
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1  Club cells_1           0.0
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1          NE_4           4.0
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1          NE_2           2.0
# ...                                                    ...           ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2          NE_3           3.0
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2          NE_2           2.0
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2          NE_1           2.0
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2          NE_4           4.0
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2          NE_1           1.0
#
#                                               specialists_pca_diffdist  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1                       NaN
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1                     Arc_5
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1                     Arc_6
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1                     Arc_5
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1                     Arc_5
# ...                                                                ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2                       NaN
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2                     Arc_1
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2                     Arc_1
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2                     Arc_1
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2                     Arc_1
#
#                                               Arc_1_PCHA_Score  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1          0.208275
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1          0.097748
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1          0.000000
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1          0.068632
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1          0.098172
# ...                                                        ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2          0.629433
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2          0.846308
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2          0.865367
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2          0.919216
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2          0.900518
#
#                                               Arc_2_PCHA_Score  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1          0.000000
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1          0.000000
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1          0.047739
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1          0.000000
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1          0.000000
# ...                                                        ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2          0.000000
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2          0.050048
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2          0.047096
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2          0.000000
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2          0.000054
#
#                                               Arc_3_PCHA_Score  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1          0.000000
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1          0.000000
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1          0.011435
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1          0.000000
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1          0.000000
# ...                                                        ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2          0.002559
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2          0.011704
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2          0.000000
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2          0.003786
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2          0.000000
#
#                                               Arc_4_PCHA_Score  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1          0.014635
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1          0.009071
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1          0.001306
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1          0.000000
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1          0.000000
# ...                                                        ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2          0.000000
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2          0.000000
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2          0.000000
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2          0.004175
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2          0.000000
#
#                                               Arc_5_PCHA_Score  \
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1          0.777090
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1          0.893181
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1          0.098623
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1          0.931368
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1          0.901828
# ...                                                        ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2          0.230872
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2          0.091940
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2          0.084478
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2          0.050617
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2          0.075877
#
#                                               Arc_6_PCHA_Score
# CellID
# gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx-M1          0.000000
# gex_possorted_bam_SJSO3:AAAGCCGCACCCACCTx-M1          0.000000
# gex_possorted_bam_SJSO3:AAACGTACAGGACCAAx-M1          0.840897
# gex_possorted_bam_SJSO3:AAAGGACGTAACGAGGx-M1          0.000000
# gex_possorted_bam_SJSO3:AAACATGCAATGAAGCx-M1          0.000000
# ...                                                        ...
# gex_possorted_bam_1WGCZ:TTTGTGTTCCTTAGGGx-M2          0.137136
# gex_possorted_bam_1WGCZ:TTTGTGGCATGGCCCAx-M2          0.000000
# gex_possorted_bam_1WGCZ:TTTGTGTTCGGCCATAx-M2          0.003060
# gex_possorted_bam_1WGCZ:TTTGTTGGTCAAAGAAx-M2          0.022206
# gex_possorted_bam_1WGCZ:TTTGTGAAGTAAACCCx-M2          0.023551
#
# [8908 rows x 64 columns]

# %% [markdown]
# # Write out data

# %%
adata.write_h5ad('../../data/combined/adata_02_filtered.h5ad')

# %%
X_magic.write_h5ad("../../data/combined/X_magic_02_filtered.h5ad")

# %% [markdown]
# ## Write out data for ParetoTI
# T ratio calculation and comparison of single cell archetypes to bulk archetypes using enrichments

# %% [markdown]
# We will run archetype analysis using ParetoTI, and compare the single cell and bulk archetypes using the Hausser code (hypergeometric tests on enrichments). We will use the PCA of the MAGIC imputed data.

# %%
X_magic_for_R = X_magic.copy()

# %%
X_magic_for_R
# Out:
# AnnData object with n_obs × n_vars = 4520 × 14120
#     obs: 'doublet_scores', 'predicted_doublets', 'initial_size_spliced', 'initial_size_unspliced', 'initial_size', 'n_counts', 'M', 'E', 'clusters_gradients', 'S_score', 'G2M_score', 'phase', 'cell_cycle_diff', 'brcd', 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_ATAC', 'nFeature_ATAC', 'nucleosome_signal', 'nucleosome_percentile', 'TSS.enrichment', 'TSS.percentile', 'barcode', 'sample', 'ATAC_snn_res.0.5', 'seurat_clusters', 'nCount_peaks', 'nFeature_peaks', 'peaks_snn_res.0.5', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.5', 'SCT.weight', 'peaks.weight', 'nCount_Imputed_counts', 'nFeature_Imputed_counts', 'nCount_gene_activity', 'nFeature_gene_activity', 'NE_score1', 'identity', 'non.NE_score1', 'comb.score', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'wsnn_res.0.5', 'specialists_pca_diffdist', 'Arc_1_PCHA_Score', 'Arc_2_PCHA_Score', 'Arc_3_PCHA_Score', 'Arc_4_PCHA_Score', 'Arc_5_PCHA_Score', 'Arc_6_PCHA_Score'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'gene_count_corr', 'mito', 'pct_dropout_by_counts', 'ambient'
#     uns: 'pca', 'neighbors', 'umap', 'identity_colors'
#     obsm: 'X_pca', 'X_umap', 'arc_distance', 'py_pcha_S'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'

# %%
#Get rid of arc_distance, which causes a problem in R
X_magic_for_R.obsm = {'X_pca':X_magic_for_R.obsm['X_pca']}

# %%
# for col in ['specialists_pca_diffdist']:
#     X_magic_for_R.obs[col]=X_magic_for_R.obs[col].cat.add_categories("Unknown").fillna('Unknown')

# %%
X_magic_for_R.obs.isnull().values.any()
# Out:
# True

# %%
X_magic_for_R.obs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4520 entries, gex_possorted_bam_SJSO3:AAACCGGCAGCCTAACx to gex_possorted_bam_SJSO3:TTTGTCCCAATCGCACx
# Data columns (total 56 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   doublet_scores            4520 non-null   float64
#  1   predicted_doublets        4520 non-null   category
#  2   initial_size_spliced      4520 non-null   uint64
#  3   initial_size_unspliced    4520 non-null   uint64
#  4   initial_size              4520 non-null   float32
#  5   n_counts                  4520 non-null   float32
#  6   M                         4520 non-null   float64
#  7   E                         4520 non-null   float64
#  8   clusters_gradients        4520 non-null   category
#  9   S_score                   4520 non-null   float64
#  10  G2M_score                 4520 non-null   float64
#  11  phase                     4520 non-null   category
#  12  cell_cycle_diff           4520 non-null   float64
#  13  brcd                      4520 non-null   category
#  14  orig.ident                4520 non-null   category
#  15  nCount_RNA                4520 non-null   float64
#  16  nFeature_RNA              4520 non-null   float64
#  17  nCount_ATAC               4520 non-null   float64
#  18  nFeature_ATAC             4520 non-null   float64
#  19  nucleosome_signal         4520 non-null   float64
#  20  nucleosome_percentile     4520 non-null   float64
#  21  TSS.enrichment            4520 non-null   float64
#  22  TSS.percentile            4520 non-null   float64
#  23  barcode                   4520 non-null   category
#  24  sample                    4520 non-null   float64
#  25  ATAC_snn_res.0.5          4520 non-null   float64
#  26  seurat_clusters           4520 non-null   float64
#  27  nCount_peaks              4520 non-null   float64
#  28  nFeature_peaks            4520 non-null   float64
#  29  peaks_snn_res.0.5         4520 non-null   float64
#  30  percent.mt                4520 non-null   float64
#  31  nCount_SCT                4520 non-null   float64
#  32  nFeature_SCT              4520 non-null   float64
#  33  SCT_snn_res.0.5           4520 non-null   float64
#  34  SCT.weight                4520 non-null   float64
#  35  peaks.weight              4520 non-null   float64
#  36  nCount_Imputed_counts     4520 non-null   float64
#  37  nFeature_Imputed_counts   4520 non-null   float64
#  38  nCount_gene_activity      4520 non-null   float64
#  39  nFeature_gene_activity    4520 non-null   float64
#  40  NE_score1                 4520 non-null   float64
#  41  identity                  4520 non-null   category
#  42  non.NE_score1             4520 non-null   float64
#  43  comb.score                4520 non-null   float64
#  44  S.Score                   4520 non-null   float64
#  45  G2M.Score                 4520 non-null   float64
#  46  Phase                     4520 non-null   category
#  47  old.ident                 4520 non-null   category
#  48  wsnn_res.0.5              4520 non-null   float64
#  49  specialists_pca_diffdist  1779 non-null   category
#  50  Arc_1_PCHA_Score          4520 non-null   float64
#  51  Arc_2_PCHA_Score          4520 non-null   float64
#  52  Arc_3_PCHA_Score          4520 non-null   float64
#  53  Arc_4_PCHA_Score          4520 non-null   float64
#  54  Arc_5_PCHA_Score          4520 non-null   float64
#  55  Arc_6_PCHA_Score          4520 non-null   float64
# dtypes: category(10), float32(2), float64(42), uint64(2)
# memory usage: 2.1+ MB

# %%
X_magic_for_R.write_h5ad("../../data/combined/X_magic_for_R_filtered.h5ad")

# %% [markdown]
# # Supervised AA

# %%
sig_matrix = pd.read_csv('/Users/smgroves/Documents/GitHub/Groves-CellSys2021/notebooks/out/bulk/sig_matrix_ParTI_2021.csv', header =0, index_col = 0)

sig_matrix = sig_matrix / np.linalg.norm(sig_matrix, axis=0)
sig_matrix.index = [i.capitalize() for i in sig_matrix.index]

# %% [markdown]
# If the below code gives an error about data shape, use `type = 'csr'`.

# %% [markdown]
# Cells with zero expression for all genes in gene signature will get scores of NaN when assigning scores in adata.obs (because these cells are filtered for the calculation).

# %%
adata, adata_small, sig_matrix2 = mb.ar.phenotyping_recipe(adata, sig_matrix,groupby = 'identity',velocity=False, type='csr')
# Out:
# Trying to set attribute `.obs` of view, copying.
# Transforming tumor data...
# Gene signature matrix now has shape:  (69, 5)
# Tumor data shortened to genes in gene list...
# (3030, 69)
# Tumor data subsetting complete.

# %%
scv.pl.scatter(adata_small, color = [i for i in adata.obs.columns if i.endswith('_Score')], smooth = True, basis = 'umap_wnn', ncols = 6, cmap = 'rocket')

# %%
scv.pl.scatter(adata, color = 'identity', smooth = True, basis = 'umap_wnn')
